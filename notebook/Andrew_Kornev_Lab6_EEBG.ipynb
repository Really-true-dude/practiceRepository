# %%
# %%bash
# # Remove the sample data folder in /content
# rm -r sample_data
#
# # Create gitignore file
# cat > .gitignore
# .*
# .gitignore

# %%
# %%bash
# # Initialize a git repository
# git init
# Out:
# Initialized empty Git repository in /content/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %%
# %%bash
# ## Create a Readme.md file in repository
# cat > README.MD
# This file contains information about this repo.
# This is a test asignment repo for EEBG summer school.
# Repository consists of asignment jupyter notebooks and sample data.

# %%
# %%bash
# ## Create repo folders
# mkdir summarydata notebook figure
# cd summarydata
# cat > README.MD
# This file contains raw data that has been used for test asignments for summer EEBG school.
# Feel free to use any of this data for your projects.

# %%
# %%bash
# cat > notebook/README.MD
# This file contains notebooks where the asignments for summer school were done.

# %%
# %%bash
# cat > figure/README.MD
# This file will contain some figures that were used for asignments if they were needed.

# %%
# %%bash
# # Download files for summarydata
# cd summarydata
# wget -nv -O IGHJ_Mouse.fa 'https://drive.google.com/uc?export=download&id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO'
# wget -nv -O IGHJ_Human.fa 'https://drive.google.com/uc?export=download&id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz'
# wget -nv -O IGHJ_Zebrafish.fa 'https://drive.google.com/uc?export=download&id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak'
# wget -nv -O titanic.csv 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#
# # This dataset is to large and requires git lfs to be stored, it will be not uploaded to git
# # wget -nv -O treesCount.csv 'https://data.cityofnewyork.us/api/views/5rq2-4hqu/rows.csv?accessType=DOWNLOAD'
# Out:
# 2024-06-28 20:25:43 URL:https://drive.usercontent.google.com/download?id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO&export=download [1178/1178] -> "IGHJ_Mouse.fa" [1]
# 2024-06-28 20:25:44 URL:https://drive.usercontent.google.com/download?id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz&export=download [2639/2639] -> "IGHJ_Human.fa" [1]
# 2024-06-28 20:25:45 URL:https://drive.usercontent.google.com/download?id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak&export=download [1034/1034] -> "IGHJ_Zebrafish.fa" [1]
# 2024-06-28 20:25:45 URL:https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv [57018/57018] -> "titanic.csv" [1]
# 2024-06-28 20:26:29 URL:https://data.cityofnewyork.us/api/views/5rq2-4hqu/rows.csv?accessType=DOWNLOAD [236024379] -> "treesCount.csv" [1]

# %%
# %%bash
# # Download asignment notebooks for the notebooks folder
# cd notebook
#
# wget --no-check-certificate "https://docs.google.com/uc?export=download&id=1fp7gwe-y8_3wIHUYXn_6GeA0hcWkI0cG" -O Andrew_Kornev_Lab1_EEBG.ipynb
# wget --no-check-certificate "https://docs.google.com/uc?export=download&id=1qpDuOJgNoxEJ3f8RuU068Fz2LvDYarE0" -O Andrew_Kornev_Lab2_EEBG.ipynb
# wget --no-check-certificate "https://docs.google.com/uc?export=download&id=1ontWm6XwQZC61AJa7igvkZwQtRS98A0E" -O Andrew_Kornev_Lab3_EEBG.ipynb
# wget --no-check-certificate "https://docs.google.com/uc?export=download&id=1nbO4jhmebAedBNq6UNaVs1ExL1WcG-YI" -O Andrew_Kornev_Lab4_EEBG.ipynb
# wget --no-check-certificate "https://docs.google.com/uc?export=download&id=1V9PVbopa0we_AxoIEN5X2vuU8v1QKLHH" -O Andrew_Kornev_Lab5_EEBG.ipynb
export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261082 (255K) [application/octet-stream]
# Saving to: ‘Andrew_Kornev_Lab5_EEBG.ipynb’
#
#      0K .......... .......... .......... .......... .......... 19% 54.8M 0s
#     50K .......... .......... .......... .......... .......... 39% 61.4M 0s
#    100K .......... .......... .......... .......... .......... 58% 67.9M 0s
#    150K .......... .......... .......... .......... .......... 78% 68.5M 0s
#    200K .......... .......... .......... .......... .......... 98% 70.9M 0s
#    250K ....                                                  100% 72.2M=0.004s
#
# 2024-06-28 20:24:30 (64.3 MB/s) - ‘Andrew_Kornev_Lab5_EEBG.ipynb’ saved [261082/261082]
#
# --2024-06-28 20:24:30--  https://docs.google.com/uc?export=download&id=1xaGOvTxQfJiESjbBCac6iVjtl3eDM5vG
# Resolving docs.google.com (docs.google.com)... 74.125.197.139, 74.125.197.138, 74.125.197.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1xaGOvTxQfJiESjbBCac6iVjtl3eDM5vG&export=download [following]
# --2024-06-28 20:24:30--  https://drive.usercontent.google.com/download?id=1xaGOvTxQfJiESjbBCac6iVjtl3eDM5vG&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 436720 (426K) [application/octet-stream]
# Saving to: ‘Andrew_Kornev_Lab5-1_EEBG.ipynb’
#
#      0K .......... .......... .......... .......... .......... 11% 47.1M 0s
#     50K .......... .......... .......... .......... .......... 23% 54.5M 0s
#    100K .......... .......... .......... .......... .......... 35% 54.0M 0s
#    150K .......... .......... .......... .......... .......... 46% 55.1M 0s
#    200K .......... .......... .......... .......... .......... 58% 53.2M 0s
#    250K .......... .......... .......... .......... .......... 70% 21.1M 0s
#    300K .......... .......... .......... .......... .......... 82% 63.9M 0s
#    350K .......... .......... .......... .......... .......... 93% 64.5M 0s
#    400K .......... .......... ......                          100% 66.9M=0.009s
#
# 2024-06-28 20:24:31 (47.0 MB/s) - ‘Andrew_Kornev_Lab5-1_EEBG.ipynb’ saved [436720/436720]
#
# --2024-06-28 20:24:31--  https://docs.google.com/uc?export=download&id=1yIjHXcKEhJNI0cpMTwtjTjLc6J906EIh
# Resolving docs.google.com (docs.google.com)... 74.125.197.139, 74.125.197.138, 74.125.197.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1yIjHXcKEhJNI0cpMTwtjTjLc6J906EIh&export=download [following]
# --2024-06-28 20:24:31--  https://drive.usercontent.google.com/download?id=1yIjHXcKEhJNI0cpMTwtjTjLc6J906EIh&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27632 (27K) [application/octet-stream]
# Saving to: ‘Andrew_Kornev_Lab6_EEBG.ipynb’
#
#      0K .......... .......... ......                          100% 40.6M=0.001s
#
# 2024-06-28 20:24:32 (40.6 MB/s) - ‘Andrew_Kornev_Lab6_EEBG.ipynb’ saved [27632/27632]

# %%
# %%bash
# # Create empty dummy png files for figure folder as no figures were required for saving or downloading during the asignment tasks
# cd figure
# touch Figure1.png
# touch Figure2a.png
# touch Figure2b.png
# touch Figure3.png
# touch Figure4.png

# %%
## Telling git who am I
# %%bash
git config --global user.email "andrekor2004@gmail.com"

# %%
### SSH key
# Generate SSH key
# %%bash
ssh-keygen -t ed25519 -C '[YOUR_EMAIL_HERE]' -f ~/.ssh/id_ed25519 -P ''
cat > ~/.ssh/config
Host *
  AddKeysToAgent yes
  IdentityFile ~/.ssh/id_ed25519
# Out:
# Generating public/private ed25519 key pair.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:pe7ufyl2KBhxd5gNL4PjVG3UHrM3ZcsW/Aipbp0A6Hw [YOUR_EMAIL_HERE]
# The key's randomart image is:
# +--[ED25519 256]--+
# |       .   o.o.  |
# |      . . o = +oo|
# |     o   +.O o.*=|
# |      + EoO + +=o|
# |       *S+ * ....|
# |      ... o o    |
# |       o.. . .   |
# |      ... + +    |
# |       o++.+     |
# +----[SHA256]-----+
# Created directory '/root/.ssh'.

# %%
# Add key to ssh-agent
# %%bash
eval "$(ssh-agent -s)"
ssh-add ~/.ssh/id_ed25519
# Out:
# Agent pid 2977
# Identity added: /root/.ssh/id_ed25519 ([YOUR_EMAIL_HERE])

# %%
# Printing public key and setting it to github account
# %%bash
cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIHnkbci78deLkIKsctxakLpDONc0eJHa+es1SBFlnuWb [YOUR_EMAIL_HERE]

# %%
## Verify key working
# %%bash
ssh -o "StrictHostKeyChecking no" -T git@github.com
# Out:
# Warning: Permanently added 'github.com' (ED25519) to the list of known hosts.
# Hi Really-true-dude! You've successfully authenticated, but GitHub does not provide shell access.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-23-092455711042> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'ssh -o "StrictHostKeyChecking no" -T git@github.com\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'ssh -o "StrictHostKeyChecking no" -T git@github.com\n'' returned non-zero exit status 1.

# %%
# Pushing results to github
# %%bash
git remote add origin git@github.com:Really-true-dude/practiceRepository.git

git branch -M master
git add .
git commit -m "Initial Commit"
git push -u origin master
# Out:
# [master e644862] Initial Commit
#  1 file changed, 683789 deletions(-)
#  delete mode 100644 summarydata/treesCount.csv
# error: remote origin already exists.
# remote: error: Trace: b91a291dadca11ad3fbc05ecd04518fcbfa4b3319adafe34b9ca16a8f9a679b2
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File summarydata/treesCount.csv is 225.09 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To github.com:Really-true-dude/practiceRepository.git
#  ! [remote rejected] master -> master (pre-receive hook declined)
# error: failed to push some refs to 'github.com:Really-true-dude/practiceRepository.git'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-29-165b935ce5bb> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'git remote add origin git@github.com:Really-true-dude/practiceRepository.git\n\ngit branch -M master\ngit add .\ngit commit -m "Initial Commit"\ngit push -u origin master\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'git remote add origin git@github.com:Really-true-dude/practiceRepository.git\n\ngit branch -M master\ngit add .\ngit commit -m "Initial Commit"\ngit push -u origin master\n'' returned non-zero exit status 1.
